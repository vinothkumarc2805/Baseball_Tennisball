# %%
import tensorflow as tf
import numpy as np
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_path = '/content/drive/My Drive/Colab Notebooks/Baseball/train'
test_path = '/content/drive/My Drive/Colab Notebooks/Baseball/test'

# %%
train_datagen  = ImageDataGenerator(rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen  = ImageDataGenerator(rescale=1./255)

# %%
train_datagenerator = train_datagen.flow_from_directory(train_path,
    target_size=(128,128),
    batch_size=40,
    class_mode='binary')

test_datagenerator = test_datagen.flow_from_directory(test_path,
    target_size=(128,128),
    batch_size=10,
    class_mode='binary')
# Out:
# Found 40 images belonging to 2 classes.
# Found 10 images belonging to 2 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3),padding='same', activation='relu', input_shape=(128,128,3)),
    tf.keras.layers.MaxPooling2D((2,2),2),
    
    tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2),2),     
     
    tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2),2),   
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               16777728
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 16,871,489
# Trainable params: 16,871,489
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
             optimizer=tf.keras.optimizers.Adam(0.001),
             metrics=['accuracy'])

# %%
DESIRED_ACCURACY = 0.85

class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
 #   acc = float(logs.get('acc'))
 #   val_acc= float(logs.get('val_acc'))
    if((logs.get('accuracy') >DESIRED_ACCURACY) and (logs.get('val_accuracy')>DESIRED_ACCURACY )):
      print("\nReached 85% accuracy so cancelling training!")
      self.model.stop_training = True

callbacks = myCallback()

# %%
model.fit_generator(
    train_datagenerator,
    epochs=100,
    validation_data = test_datagenerator,
    callbacks = [callbacks]
    )
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.6921 - accuracy: 0.5000 - val_loss: 0.6903 - val_accuracy: 0.7000
# Epoch 2/100
# 1/1 [==============================] - 0s 82ms/step - loss: 0.6757 - accuracy: 0.8500 - val_loss: 0.7007 - val_accuracy: 0.5000
# Epoch 3/100
# 1/1 [==============================] - 0s 82ms/step - loss: 0.6654 - accuracy: 0.5500 - val_loss: 0.7009 - val_accuracy: 0.5000
# Epoch 4/100
# 1/1 [==============================] - 0s 93ms/step - loss: 0.6506 - accuracy: 0.5500 - val_loss: 0.6689 - val_accuracy: 0.8000
# Epoch 5/100
# 1/1 [==============================] - 0s 102ms/step - loss: 0.6285 - accuracy: 0.8750 - val_loss: 0.6658 - val_accuracy: 0.7000
# Epoch 6/100
# 1/1 [==============================] - 0s 90ms/step - loss: 0.5925 - accuracy: 0.8500 - val_loss: 0.6683 - val_accuracy: 0.7000
# Epoch 7/100
# 1/1 [==============================] - 0s 83ms/step - loss: 0.5458 - accuracy: 0.8000 - val_loss: 0.6522 - val_accuracy: 0.7000
# Epoch 8/100
# 1/1 [==============================] - 0s 97ms/step - loss: 0.5072 - accuracy: 0.8000 - val_loss: 0.7880 - val_accuracy: 0.5000
# Epoch 9/100
# 1/1 [==============================] - 0s 91ms/step - loss: 0.5168 - accuracy: 0.6750 - val_loss: 0.6922 - val_accuracy: 0.5000
# Epoch 10/100
# 1/1 [==============================] - 0s 84ms/step - loss: 0.4545 - accuracy: 0.7750 - val_loss: 0.6633 - val_accuracy: 0.6000
# Epoch 11/100
# 1/1 [==============================] - 0s 84ms/step - loss: 0.4099 - accuracy: 0.9250 - val_loss: 0.6594 - val_accuracy: 0.6000
# Epoch 12/100
# 1/1 [==============================] - 0s 93ms/step - loss: 0.3761 - accuracy: 0.9250 - val_loss: 0.5984 - val_accuracy: 0.8000
# Epoch 13/100
# 1/1 [==============================] - 0s 89ms/step - loss: 0.3277 - accuracy: 0.9250 - val_loss: 0.5694 - val_accuracy: 0.8000
# Epoch 14/100
# 1/1 [==============================] - 0s 84ms/step - loss: 0.2747 - accuracy: 0.9000 - val_loss: 0.5865 - val_accuracy: 0.6000
# Epoch 15/100
# 1/1 [==============================] - 0s 84ms/step - loss: 0.2366 - accuracy: 0.9250 - val_loss: 0.5649 - val_accuracy: 0.7000
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 0.2049 - accuracy: 0.9250
# Reached 85% accuracy so cancelling training!
# 1/1 [==============================] - 0s 98ms/step - loss: 0.2049 - accuracy: 0.9250 - val_loss: 0.6461 - val_accuracy: 0.9000

# %%
model.save('/content/drive/My Drive/Colab Notebooks/Baseball/Baseballmodel.h5')

# %%
from tensorflow.keras.preprocessing import image

# %%
path = '/content/drive/My Drive/Colab Notebooks/Baseball/test/baseball/baseball-4003006_640.jpg'
img = image.load_img(path, target_size=(128, 128))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
classes = model.predict(images)
print(classes[0])
if classes[0]<0.5:
    print("Given image contains a Baseball")
else:
    print("Given image contains a Tennis Ball")
# Out:
# [0.]
# Given image contains a Baseball
